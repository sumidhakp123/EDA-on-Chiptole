# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file=r'chipotle.tsv'

# %%
data=pd.read_csv(file, sep='\t')

# %%
data.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
data.shape
# Out:
# (4622, 5)

# %%
data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
data.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
def temp(val):
    val = str(val)
    x = ""
    for char in val:
        if char == '.':
            x = x+char
        elif char.isdigit():
            x = x+char
    if len(x)> 0:
        return x
    else:
        return np.nan

# %%
data['item_price'] = data['item_price'].apply(temp)

# %%
data.rename(columns = {'item_price':'item_price'},inplace = True)

# %%
data.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#    item_price in $
# 0             2.39
# 1             3.39

# %%
data['item_price'] = data['item_price'].astype('float')

# %%
data.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
'''Task A: Identify the star product for the company?'''
data.groupby('item_name').agg({'quantity':'sum','item_price':'sum'}).sort_values(by = 'quantity', ascending = False)
# Out:
#                                        quantity  item_price
# item_name
# Chicken Bowl                                761     7342.73
# Chicken Burrito                             591     5575.82
# Chips and Guacamole                         506     2201.04
# Steak Burrito                               386     3851.43
# Canned Soft Drink                           351      438.75
# Chips                                       230      494.34
# Steak Bowl                                  221     2260.19
# Bottled Water                               211      302.56
# Chips and Fresh Tomato Salsa                130      361.36
# Canned Soda                                 126      137.34
# Chicken Salad Bowl                          123     1228.75
# Chicken Soft Tacos                          120     1108.09
# Side of Chips                               110      185.90
# Veggie Burrito                               97      934.77
# ...

# %%
# Chicken Bowl is the star Product. It is sold the most

# %%
data['choice_description'].nunique()
# Out:
# 1043

# %%
'''Task B: What’s the most selling product and most expensive product?'''
data.groupby('item_name').agg({'quantity':'sum'}).sort_values(by = 'quantity', ascending = False)
# Out:
#                                        quantity
# item_name
# Chicken Bowl                                761
# Chicken Burrito                             591
# Chips and Guacamole                         506
# Steak Burrito                               386
# Canned Soft Drink                           351
# Chips                                       230
# Steak Bowl                                  221
# Bottled Water                               211
# Chips and Fresh Tomato Salsa                130
# Canned Soda                                 126
# Chicken Salad Bowl                          123
# Chicken Soft Tacos                          120
# Side of Chips                               110
# Veggie Burrito                               97
# Barbacoa Burrito                             91
# Veggie Bowl                                  87
# Carnitas Bowl                                71
# Barbacoa Bowl                                66
# ...

# %%
data.groupby('item_name').agg({'item_price':'sum'}).sort_values(by = 'item_price', ascending = False)
# Out:
#                                        item_price
# item_name
# Chicken Bowl                              7342.73
# Chicken Burrito                           5575.82
# Steak Burrito                             3851.43
# Steak Bowl                                2260.19
# Chips and Guacamole                       2201.04
# Chicken Salad Bowl                        1228.75
# Chicken Soft Tacos                        1108.09
# Veggie Burrito                             934.77
# Barbacoa Burrito                           894.75
# Veggie Bowl                                867.99
# Carnitas Bowl                              736.71
# Barbacoa Bowl                              672.36
# Carnitas Burrito                           597.83
# Steak Soft Tacos                           536.05
# Chips                                      494.34
# Chicken Crispy Tacos                       472.13
# Canned Soft Drink                          438.75
# Carnitas Soft Tacos                        375.94
# ...

# %%
# Chicken Bowl is the most selling and the most expensive product.

# %%
'''Task C: Assuming a profit markup of 60% on each product, which product has the highest share in revenue?'''
# IF there is a 60% profit on each product, then there is no need to consider this point.
data.groupby('item_name').agg({'quantity':'sum','item_price':'sum'}).sort_values(by = 'quantity', ascending = False)
# Chicken Bowl has the highest share in revenue.Reason ITs sold the most and has the price item price.
# Out:
#                                        quantity  item_price
# item_name
# Chicken Bowl                                761     7342.73
# Chicken Burrito                             591     5575.82
# Chips and Guacamole                         506     2201.04
# Steak Burrito                               386     3851.43
# Canned Soft Drink                           351      438.75
# Chips                                       230      494.34
# Steak Bowl                                  221     2260.19
# Bottled Water                               211      302.56
# Chips and Fresh Tomato Salsa                130      361.36
# Canned Soda                                 126      137.34
# Chicken Salad Bowl                          123     1228.75
# Chicken Soft Tacos                          120     1108.09
# Side of Chips                               110      185.90
# Veggie Burrito                               97      934.77
# ...

# %%
'''Task D: Company is planning is reducing the size of Menu. 
Kindly recommend the menu items to keep and which one to drop. Please explain briefly'''
# Out:
# 'Task D: Company is planning is reducing the size of Menu. \nKindly recommend the menu items to keep and which one to drop. Please explain briefly'

# %%
product_revenue = data.groupby('item_name').agg({'item_price':'sum'}).sort_values(by =['item_price'],ascending = [False])
total_revenue = data['item_price'].sum()
share=(product_revenue/total_revenue)*100
keep =share[share>= 1]
keep
# Out:
#                                        item_price
# item_name
# Chicken Bowl                            21.283177
# Chicken Burrito                         16.161722
# Steak Burrito                           11.163513
# Steak Bowl                               6.551245
# Chips and Guacamole                      6.379796
# Chicken Salad Bowl                       3.561578
# Chicken Soft Tacos                       3.211840
# Veggie Burrito                           2.709466
# Barbacoa Burrito                         2.593466
# Veggie Bowl                              2.515901
# Carnitas Bowl                            2.135381
# Barbacoa Bowl                            1.948861
# Carnitas Burrito                         1.732833
# Steak Soft Tacos                         1.553761
# Chips                                    1.432863
# Chicken Crispy Tacos                     1.368486
# Canned Soft Drink                        1.271733
# Carnitas Soft Tacos                      1.089676
# ...

# %%
drop =share[share<1]
drop
# Out:
#                                        item_price
# item_name
# Chicken Bowl                                  NaN
# Chicken Burrito                               NaN
# Steak Burrito                                 NaN
# Steak Bowl                                    NaN
# Chips and Guacamole                           NaN
# Chicken Salad Bowl                            NaN
# Chicken Soft Tacos                            NaN
# Veggie Burrito                                NaN
# Barbacoa Burrito                              NaN
# Veggie Bowl                                   NaN
# Carnitas Bowl                                 NaN
# Barbacoa Bowl                                 NaN
# Carnitas Burrito                              NaN
# Steak Soft Tacos                              NaN
# Chips                                         NaN
# Chicken Crispy Tacos                          NaN
# Canned Soft Drink                             NaN
# Carnitas Soft Tacos                           NaN
# ...
